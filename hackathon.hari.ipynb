# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("adult.csv")

# %%
data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
data.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        119
# capital-loss         92
# hours-per-week       94
# country              42
# salary                2
# dtype: int64

# %%
data.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Binary Features
plt.figure(figsize=(20, 5))


plt.subplot(131)
sns.countplot(data['hours-per-week'])
plt.xlabel('hours-per-week')
plt.ylabel('Frequency')


plt.subplot(132)
sns.countplot(data['education-num'])
plt.xlabel('education-num')
plt.ylabel('Frequency')


plt.subplot(133)
sns.countplot(data['age'])
plt.xlabel('age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %%
plt.figure(figsize=(22,6))
df1 = data.drop(['workclass','education','marital-status','occupation','relationship','race','sex','capital-gain','country','salary'],axis=1)
ax = sns.heatmap(data.corr(),xticklabels=df1.columns,yticklabels=df1.columns,linewidths=.2)

# %%
df1.head()
# Out:
#    age  fnlwgt  education-num  capital-loss  hours-per-week
# 0   39   77516             13             0              40
# 1   50   83311             13             0              13
# 2   38  215646              9             0              40
# 3   53  234721              7             0              40
# 4   28  338409             13             0              40

# %%
x = df1.drop(['hours-per-week'],axis=1)
y = df1['hours-per-week']

# %%
from sklearn.model_selection import train_test_split 
train_x,test_x,train_y,test_y = train_test_split(x,y,random_state =10,shuffle=False)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df2 = scaler.fit_transform(df1)

# %%
scaled_data = pd.DataFrame(scaled_df2)

# %%
scaled_data.head()
# Out:
#           0         1         2        3         4
# 0  0.030671 -1.063611  1.134739 -0.21666 -0.035429
# 1  0.837109 -1.008707  1.134739 -0.21666 -2.222153
# 2 -0.042642  0.245079 -0.420060 -0.21666 -0.035429
# 3  1.057047  0.425801 -1.197459 -0.21666 -0.035429
# 4 -0.775768  1.408176  1.134739 -0.21666 -0.035429

# %%
from sklearn.cluster import KMeans
kmean =KMeans(n_clusters=2)

# %%
kmean.fit(scaled_data)
# Out:
# KMeans(n_clusters=2)

# %%
pred = kmean.predict(scaled_data)

# %%
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
pd.DataFrame(pred).value_counts()
# Out:
# 0    31077
# 1     1484
# dtype: int64

# %%
kmean.score(scaled_data)
# Out:
# -130919.48543866424

# %%
kmean.inertia_
# Out:
# 130919.48543866423

# %%
SSE = []

# %%
for cluster in range(1,50):
    kmean = KMeans(n_jobs = -1,n_clusters = cluster)
    kmean.fit(scaled_data)
    SSE.append(kmean.inertia_)

# %%
plt.figure(figsize=(12,6))
frame_scaled = pd.DataFrame({'cluster':range(1,50),'SSE':SSE})
plt.plot(frame_scaled['cluster'],frame_scaled['SSE'],marker='o')
plt.xlabel('cluster')
plt.ylabel('SSE')
# Out:
# Text(0, 0.5, 'SSE')

# %%
kmean = KMeans(n_jobs = -1,n_clusters = 40)
kmean.fit(scaled_data)
# Out:
# KMeans(n_clusters=40, n_jobs=-1)

# %%
pred = kmean.predict(scaled_data)
pd.DataFrame(pred).value_counts()
# Out:
# 39    2420
# 1     2210
# 5     1701
# 13    1400
# 28    1375
# 14    1307
# 18    1268
# 21    1263
# 25    1210
# 29    1162
# 24    1153
# 27    1097
# 3     1023
# 19     919
# 0      897
# 22     873
# 37     834
# 32     824
# 16     667
# 4      662
# 10     648
# 38     620
# 6      607
# 17     606
# 35     603
# 8      533
# 31     523
# 36     496
# 12     437
# 11     407
# 26     405
# 33     403
# 15     352
# 2      345
# 23     291
# 9      288
# 7      238
# 20     238
# 30     231
# 34      25
# dtype: int64

# %%
pd.DataFrame(pred).sample(20)
# Out:
#         0
# 2371    6
# 30099  17
# 4531   39
# 10504   3
# 22780  13
# 4139   39
# 23162   3
# 18567   3
# 10050   1
# 1636   15
# 10744   5
# 29478   1
# 4244   28
# 30913  35
# 5269   10
# 32033  27
# 11466  12
# 31457   1
# 29068  13
# 681     1

# %%
kmean.score(scaled_data)
# Out:
# -26423.92391573006
